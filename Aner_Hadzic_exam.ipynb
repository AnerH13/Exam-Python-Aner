# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("/BKNG.csv")
#1
len(df1[(df1['Close']==df1['Adj Close'])])
len(df1)
#BKNG has no difference between the Close and Adj Close columns. So yes, there is

#2
df2 = pd.read_csv("/BK.csv")
df3 = pd.read_csv("/DPZ.csv")
df4 = pd.read_csv("/DTE.csv")
df1['Adj Close'].agg([ max, min]).reset_index()
df1['Adj Close'].max()
#the highest price for BKNG is 2703.260009765625, the lowest price is 1152.239990234375
df2['Adj Close'].agg([ max, min]).reset_index()
#the highest price for BK is 62.06522750854492, the lowest price is 25.285505294799805
df3['Adj Close'].agg([ max, min]).reset_index()
#the highest price for DPZ is 564.3300170898438, the lowest price is 165.92910766601562
df4['Adj Close'].agg([ max, min]).reset_index()
#the highest price for DTE is 139.119995, the lowest price is 61.661922

#3
df1['pct_change'] = df1['Adj Close'].pct_change()
df1['log_ret'] = np.log(df1['Adj Close']) - np.log(df1['Adj Close'].shift(1))
df1['log_ret'].agg([ max, min,np.mean,np.median]).reset_index()

df2['pct_change'] = df2['Adj Close'].pct_change()
df2['log_ret'] = np.log(df2['Adj Close']) - np.log(df2['Adj Close'].shift(1))
df2['log_ret'].agg([ max, min,np.mean,np.median]).reset_index()

df3['pct_change'] = df3['Adj Close'].pct_change()
df3['log_ret'] = np.log(df3['Adj Close']) - np.log(df3['Adj Close'].shift(1))
df3['log_ret'].agg([ max, min,np.mean,np.median]).reset_index()

df4['pct_change'] = df4['Adj Close'].pct_change()
df4['log_ret'] = np.log(df4['Adj Close']) - np.log(df4['Adj Close'].shift(1))
df4['log_ret'].agg([ max, min,np.mean,np.median]).reset_index()

#4
df1['log_ret'].idxmax(axis = 0)
df1['log_ret'].idxmin(axis = 0)

df2['log_ret'].idxmax(axis = 0)
df2['log_ret'].idxmin(axis = 0)

df3['log_ret'].idxmax(axis = 0)
df3['log_ret'].idxmin(axis = 0)

df4['log_ret'].idxmax(axis = 0)
df4['log_ret'].idxmin(axis = 0)

#5

#6
Total1 = df1['log_ret'].sum()
Total1
Total2 = df2['log_ret'].sum()
Total2
Total3 = df3['log_ret'].sum()
Total3
Total4 = df4['log_ret'].sum()
Total4
#DPZ has the highest total return (0.7882065535055736)
#7
pd.concat([df1,df2,df3,df4]).boxplot(column='log_ret',by=DataFrame)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-236e2bacd6a0> in <cell line: 64>()
#      62 #DPZ has the highest total return (0.7882065535055736)
#      63 #7
# ---> 64 pd.concat([df1,df2,df3,df4]).boxplot(column='log_ret',by=DataFrame)
#
# NameError: name 'DataFrame' is not defined

# %%
#1
sp = pd.read_csv("/companies_no_subindustry.csv")
sp['included'].isna().sum()
#45 companies

#2

sp1 = sp['included'].dropna()
sp1.max()
print(sp.loc['31.12.2012', "Symbol"])

#3
sp['GICS_Sector'].describe()
sp['GICS_Sector'].hist()

#4
state = sp["hq"].apply(lambda x: x[1].split()[0])
sp2

#5
ies = pd.read_csv("/companies_subindustry.csv")
sp.merge(ies, on='Symbol')
# Out:
#     Symbol              Security             GICS_Sector  \
# 0      MMM                    3M             Industrials
# 1      AOS           A. O. Smith             Industrials
# 2      ABT                Abbott             Health Care
# 3     ABBV                AbbVie             Health Care
# 4     ABMD               Abiomed             Health Care
# ..     ...                   ...                     ...
# 498    YUM           Yum! Brands  Consumer Discretionary
# 499   ZBRA    Zebra Technologies  Information Technology
# 500    ZBH         Zimmer Biomet             Health Care
# 501   ZION  Zions Bancorporation              Financials
# 502    ZTS                Zoetis             Health Care
#
#                           hq    included      Founded  \
# 0      Saint Paul, Minnesota  09.08.1976         1902
# 1       Milwaukee, Wisconsin  26.07.2017         1916
# 2    North Chicago, Illinois  31.03.1964         1888
# 3    North Chicago, Illinois  31.12.2012  2013 (1888)
# ...
